# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('./scv.csv',encoding='cp949')
df.head()
# Out:
#            화재발생년월일     시도 시·군·구   읍면동         화재유형  발화열원대분류   발화열원소분류 발화요인대분류  \
# 0  2019-01-01 0:03    강원도   삼척시   오분동  기타(쓰레기 화재등)  폭발물, 폭죽        폭죽     부주의
# 1  2019-01-01 0:06    경기도   평택시   안중읍       건축,구조물       미상        미상      미상
# 2  2019-01-01 0:40  서울특별시   성북구  하월곡동     자동차,철도차량       미상        미상      미상
# 3  2019-01-01 0:52    경기도   이천시   설성면  기타(쓰레기 화재등)  화학적 발화열     화학반응열  화학적 요인
# 4  2019-01-01 1:06  부산광역시  부산진구   당감동       건축,구조물     작동기기  기타(작동기기)  전기적 요인
#
#        발화요인소분류   최초착화물대분류     최초착화물소분류  인명피해(명)소계  사망  부상  재산피해소계     장소대분류  \
# 0         폭죽놀이  종이,목재,건초등       풀, 나뭇잎          1   0   1       0        기타
# 1           미상         미상           미상          0   0   0   14900        주거
# 2           미상         미상           미상          0   0   0    3642  자동차,철도차량
# 3         자연발화  종이,목재,건초등       풀, 나뭇잎          0   0   0    1848        기타
# 4  절연열화에 의한 단락      전기,전자  전기, 전자기기 기판          0   0   0      45     기타서비스
#
#    장소중분류   장소소분류
# 0     야외    기타야외
# 1   단독주택    단독주택
# 2    자동차   승용자동차
# 3     야외     야적장
# 4  기타건축물  기타 건축물

# %%
gb1 =df[(df['장소대분류'] == '교육시설')].groupby(by='장소소분류')
gb1

# %%
gb1_gb=gb1.count()
gb1_gb
# Out:
#           화재발생년월일  시도  시·군·구  읍면동  화재유형  발화열원대분류  발화열원소분류  발화요인대분류  발화요인소분류  \
# 장소소분류
# 고등학교           30  30     30   30    30       30       30       30       30
# 교육원             8   8      8    8     8        8        8        8        8
# 기타 연구,학원       14  14     14   14    14       14       14       14       14
# 기타 학교           7   7      7    7     7        7        7        7        7
# 대학교            64  64     64   64    64       64       64       64       64
# 도서관             6   6      6    6     6        6        6        6        6
# 연구소            29  29     29   29    29       29       29       29       29
# 예체능학원          14  14     14   14    14       14       14       14       14
# 외국어학원          14  14     14   14    14       14       14       14       14
# 일반학원           53  53     53   53    53       53       53       53       53
# 종합학원            3   3      3    3     3        3        3        3        3
# 중학교            26  26     26   26    26       26       26       26       26
# 직업훈련소           1   1      1    1     1        1        1        1        1
# 초등학교           43  43     43   43    43       43       43       43       43
# 특수학교            2   2      2    2     2        2        2        2        2
#
#           최초착화물대분류  최초착화물소분류  인명피해(명)소계  사망  부상  재산피해소계  장소대분류  장소중분류
# 장소소분류
# 고등학교            30        30         30  30  30      30     30     30
# 교육원              8         8          8   8   8       8      8      8
# 기타 연구,학원        14        14         14  14  14      14     14     14
# 기타 학교            7         7          7   7   7       7      7      7
# 대학교             64        64         64  64  64      64     64     64
# 도서관              6         6          6   6   6       6      6      6
# 연구소             29        29         29  29  29      29     29     29
# 예체능학원           14        14         14  14  14      14     14     14
# 외국어학원           14        14         14  14  14      14     14     14
# 일반학원            53        53         53  53  53      53     53     53
# 종합학원             3         3          3   3   3       3      3      3
# 중학교             26        26         26  26  26      26     26     26
# 직업훈련소            1         1          1   1   1       1      1      1
# 초등학교            43        43         43  43  43      43     43     43
# 특수학교             2         2          2   2   2       2      2      2

# %%
plt.rc('font', family='Malgun Gothic')
gb1_gb['장소대분류'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (8,5)
