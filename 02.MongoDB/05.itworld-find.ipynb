# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.itworld.co.kr/main/'

res = requests.get(url)
soup = BeautifulSoup(res.content, 'html.parser')
from IPython.display import Image

# %%
li=soup.find_all('ul','default_font color_deep_gray hot_news_list_ title_h3')
print(len(li))
for lis in li:
    print(lis.text)
# Out:
# 1
#
#
# 구글 픽셀 6 시리즈 리뷰 | 아이폰과 갤럭시를 겨냥한 크고 화려한 스마트폰
#  1일 전
#
#
# "서버를 속여 공격한다" SSRF 공격의 동작 방식과 대처법
#  1일 전
#
#
# ‘근무 환경 개선은 팀즈로’ 마이크로소프트, 일선 직원 위한 신기능 대거 출시
#  1일 전
#
#
# 워크스페이스 개편한 구글, 기업 시장 점유율은 여전히 장벽
#  1일 전
#
#
# 랜섬웨어 보험 청구 감소, 사이버 보험 시장에 큰 파장 예상
#  1일 전

# %%
lis = soup.find_all('li', 'font_bold')
for li in lis:
    print(li)
    print('--------')
# Out:
# <li class="font_bold" style="overflow: hidden;">
# <div class="font_limit fl" style="width:545px;"><a href="/news/211814">구글 픽셀 6 시리즈 리뷰 | 아이폰과 갤럭시를 겨냥한 크고 화려한 스마트폰</a></div>
# <div class="news_list_time font_11 color_black default_small_font fr"><i class="icon-time news_list_time_icon color_light_gray font_12 default_small_font"></i> 1일 전</div>
# </li>
# --------
# <li class="font_bold" style="overflow: hidden;">
# <div class="font_limit fl" style="width:545px;"><a href="/news/211794">"서버를 속여 공격한다" SSRF 공격의 동작 방식과 대처법</a></div>
# <div class="news_list_time font_11 color_black default_small_font fr"><i class="icon-time news_list_time_icon color_light_gray font_12 default_small_font"></i> 1일 전</div>
# </li>
# --------
# <li class="font_bold" style="overflow: hidden;">
# <div class="font_limit fl" style="width:545px;"><a href="/news/211789">‘근무 환경 개선은 팀즈로’ 마이크로소프트, 일선 직원 위한 신기능 대거 출시</a></div>
# <div class="news_list_time font_11 color_black default_small_font fr"><i class="icon-time news_list_time_icon color_light_gray font_12 default_small_font"></i> 1일 전</div>
# </li>
# --------
# <li class="font_bold" style="overflow: hidden;">
# <div class="font_limit fl" style="width:545px;"><a href="/news/211779">워크스페이스 개편한 구글, 기업 시장 점유율은 여전히 장벽</a></div>
# <div class="news_list_time font_11 color_black default_small_font fr"><i class="icon-time news_list_time_icon color_light_gray font_12 default_small_font"></i> 1일 전</div>
# </li>
# --------
# <li class="font_bold" style="overflow: hidden;">
# <div class="font_limit fl" style="width:545px;"><a href="/news/211774">랜섬웨어 보험 청구 감소, 사이버 보험 시장에 큰 파장 예상</a></div>
# <div class="news_list_time font_11 color_black default_small_font fr"><i class="icon-time news_list_time_icon color_light_gray font_12 default_small_font"></i> 1일 전</div>
# </li>
# --------
# <li class="foot_head_font color_white font_14 font_bold font_Italic">ITWorld</li>
# --------
# <li class="foot_head_font color_white font_14 font_bold font_Italic">News</li>
# --------
# <li class="foot_head_font color_white font_14 font_bold font_Italic">Topics</li>
# --------
# <li class="foot_head_font color_white font_14 font_bold font_Italic">Business</li>
# --------
# <li class="foot_head_font color_white font_14 font_bold font_Italic">Join Us On</li>
# --------

# %%
list_titles= []
list_time= []

# %%
#titles = soup.select('ul.default_font.color_deep_gray.hot_news_list_.title_h3 > li.font_bold>div.font_limit.fl')
#titles

titles = soup.select('ul.default_font.color_deep_gray.hot_news_list_.title_h3 > li.font_bold>div.font_limit.fl')
for title in titles:
    list_titles.append(title.text.strip())

# %%
times = soup.select('ul.default_font.color_deep_gray.hot_news_list_.title_h3 > li.font_bold>div.news_list_time.font_11.color_black.default_small_font.fr')
for time in times:
    list_time.append(time.text.strip())

# %%
for i in range(len(list_titles)):
    list_all.append([list_titles[i], list_time[i]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11304/3316361179.py in <module>
#       1 for i in range(len(list_titles)):
# ----> 2     list_all.append([list_titles[i], list_time[i]])
#
# NameError: name 'list_all' is not defined

# %%
for list_i in list_all:
    print(list_i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11304/1451442661.py in <module>
# ----> 1 for list_i in list_all:
#       2     print(list_i)
#
# NameError: name 'list_all' is not defined
