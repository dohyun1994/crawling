# %%
print("hello")
# Out:
# hello

# %%
a= 3
b= 5
print(a + b)
print(a-b)
# Out:
# 8
# -2

# %%
a/b
# Out:
# 0.6

# %% [markdown]
# 제목쓰기
# 1.aaa

# %% [markdown]
# # 제목1

# %% [markdown]
# ## 제목 2 ->

# %% [markdown]
# ### 제목 3 ->

# %% [markdown]
# #### 제목4 ->

# %% [markdown]
# ##### 제목 기울어 진 것

# %% [markdown]
# # 제목
# - 내용 1
#     - 아래 단계 내용
# - 내용 2

# %%
print(a+b)
# Out:
# 8
