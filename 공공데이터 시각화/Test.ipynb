# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./fire_2019_eng.csv', encoding='cp949')
df
# Out:
#                    Date     SiDo SiGunGu EupMyeonDong         Type  Source1  \
# 0       2019-01-01 0:03      강원도     삼척시          오분동  기타(쓰레기 화재등)  폭발물, 폭죽
# 1       2019-01-01 0:06      경기도     평택시          안중읍       건축,구조물       미상
# 2       2019-01-01 0:40    서울특별시     성북구         하월곡동     자동차,철도차량       미상
# 3       2019-01-01 0:52      경기도     이천시          설성면  기타(쓰레기 화재등)  화학적 발화열
# 4       2019-01-01 1:06    부산광역시    부산진구          당감동       건축,구조물     작동기기
# ...                 ...      ...     ...          ...          ...      ...
# 40098  2019-12-31 22:33      경기도     파주시          광탄면       건축,구조물     작동기기
# 40099  2019-12-31 22:45     경상북도     경산시          남방동       건축,구조물       미상
# 40100  2019-12-31 22:47    부산광역시      남구          문현동       건축,구조물     작동기기
# 40101  2019-12-31 23:05  제주특별자치도     제주시         외도일동       건축,구조물     작동기기
# 40102  2019-12-31 23:18    인천광역시     남동구          고잔동       건축,구조물     작동기기
#
#           Source2  Cause1        Cause2     Start1             Start2  \
# 0              폭죽     부주의          폭죽놀이  종이,목재,건초등             풀, 나뭇잎
# 1              미상      미상            미상         미상                 미상
# 2              미상      미상            미상         미상                 미상
# 3           화학반응열  화학적 요인          자연발화  종이,목재,건초등             풀, 나뭇잎
# 4        기타(작동기기)  전기적 요인   절연열화에 의한 단락      전기,전자        전기, 전자기기 기판
# ...           ...     ...           ...        ...                ...
# 40098  전기적 아크(단락)  전기적 요인   접촉불량에 의한 단락      전기,전자               전선피복
# 40099          미상      미상            미상  종이,목재,건초등                 건초
# 40100   기기 전도,복사열     부주의       음식물 조리중         식품                튀김유
# 40101   기기 전도,복사열     부주의      가연물 근접방치       합성수지  플라스틱, PVC, 비닐, 장판
# 40102  전기적 아크(단락)  전기적 요인  압착,손상에 의한 단락      전기,전자               전선피복
#
#        Members  Death  Injury  Moneys     Area1  Area2     Area3
# 0            1      0       1       0        기타     야외      기타야외
# 1            0      0       0   14900        주거   단독주택      단독주택
# 2            0      0       0    3642  자동차,철도차량    자동차     승용자동차
# 3            0      0       0    1848        기타     야외       야적장
# 4            0      0       0      45     기타서비스  기타건축물    기타 건축물
# ...        ...    ...     ...     ...       ...    ...       ...
# 40098        0      0       0   23707      산업시설   공장시설  제재 및 목공업
# 40099        0      0       0    3542      산업시설  동식물시설  기타 동식물시설
# 40100        0      0       0       0   판매,업무시설   일반업무      오피스텔
# 40101        0      0       0     105   판매,업무시설   판매시설   할인점(마트)
# 40102        0      0       0    3879      산업시설   공장시설  전기, 전자공업
#
# [40103 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Date', 'SiDo', 'SiGunGu', 'EupMyeonDong', 'Type', 'Source1', 'Source2',
#        'Cause1', 'Cause2', 'Start1', 'Start2', 'Members', 'Death', 'Injury',
#        'Moneys', 'Area1', 'Area2', 'Area3'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40103 entries, 0 to 40102
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          40103 non-null  object
#  1   SiDo          40103 non-null  object
#  2   SiGunGu       40103 non-null  object
#  3   EupMyeonDong  40103 non-null  object
#  4   Type          40103 non-null  object
#  5   Source1       40103 non-null  object
#  6   Source2       40103 non-null  object
#  7   Cause1        40103 non-null  object
#  8   Cause2        40103 non-null  object
#  9   Start1        40103 non-null  object
#  10  Start2        40103 non-null  object
#  11  Members       40103 non-null  int64
#  12  Death         40103 non-null  int64
#  13  Injury        40103 non-null  int64
#  14  Moneys        40103 non-null  int64
#  15  Area1         40103 non-null  object
#  16  Area2         40103 non-null  object
#  17  Area3         40103 non-null  object
# dtypes: int64(4), object(14)
# memory usage: 5.5+ MB

# %%
df.describe()
# Out:
#             Members         Death        Injury        Moneys
# count  40103.000000  40103.000000  40103.000000  4.010300e+04
# mean       0.062714      0.007107      0.055607  2.140728e+04
# std        0.537258      0.093552      0.510525  8.623230e+05
# min        0.000000      0.000000      0.000000  0.000000e+00
# 25%        0.000000      0.000000      0.000000  9.900000e+01
# 50%        0.000000      0.000000      0.000000  5.280000e+02
# 75%        0.000000      0.000000      0.000000  3.106000e+03
# max       59.000000      3.000000     56.000000  1.185201e+08

# %%
df.index.values
# Out:
# array([    0,     1,     2, ..., 40100, 40101, 40102], dtype=int64)

# %%
df[['Cause1', 'Cause2']]
# Out:
#        Cause1        Cause2
# 0         부주의          폭죽놀이
# 1          미상            미상
# 2          미상            미상
# 3      화학적 요인          자연발화
# 4      전기적 요인   절연열화에 의한 단락
# ...       ...           ...
# 40098  전기적 요인   접촉불량에 의한 단락
# 40099      미상            미상
# 40100     부주의       음식물 조리중
# 40101     부주의      가연물 근접방치
# 40102  전기적 요인  압착,손상에 의한 단락
#
# [40103 rows x 2 columns]

# %%
gb1=df.groupby(['Cause1'])[['Cause2']].count()
gb1
# Out:
#           Cause2
# Cause1
# 가스누출(폭발)     162
# 교통사고         433
# 기계적 요인      4046
# 기타           452
# 미상          3778
# 방화           370
# 방화의심         435
# 부주의        20149
# 자연적인 요인      195
# 전기적 요인      9459
# 화학적 요인       624

# %%
df.groupby('Cause1').get_group('Cause2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13500/2384581961.py in <module>
# ----> 1 df.groupby('Cause1').get_group('Cause2')
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     752         inds = self._get_index(name)
#     753         if not len(inds):
# --> 754             raise KeyError(name)
#     755
#     756         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: 'Cause2'

# %%
len(gb1)
# Out:
# 11

# %%
gb1.count()
# Out:
# Cause2    11
# dtype: int64

# %%
n

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['가스누출(폭발)', '교통사고', '기계적 요인', '기타', '미상', '방화', '방화의심', '부주의', '자연적인 요인', '전기적 요인', '화학적 요인']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13500/2426824358.py in <module>
#       6 colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']
#       7
# ----> 8 plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
#       9 plt.show()
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    3004         textprops=None, center=(0, 0), frame=False,
#    3005         rotatelabels=False, *, normalize=None, data=None):
# -> 3006     return gca().pie(
#    3007         x, explode=explode, labels=labels, colors=colors,
#    3008         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3057             explode = [0] * len(x)
#    3058         if len(x) != len(labels):
# -> 3059             raise ValueError("'label' must be of length 'x'")
#    3060         if len(x) != len(explode):
#    3061             raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'
