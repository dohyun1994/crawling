# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv('./scv.csv',encoding='cp949')
iris
# Out:
#                 화재발생년월일       시도 시·군·구   읍면동         화재유형  발화열원대분류  \
# 0       2019-01-01 0:03      강원도   삼척시   오분동  기타(쓰레기 화재등)  폭발물, 폭죽
# 1       2019-01-01 0:06      경기도   평택시   안중읍       건축,구조물       미상
# 2       2019-01-01 0:40    서울특별시   성북구  하월곡동     자동차,철도차량       미상
# 3       2019-01-01 0:52      경기도   이천시   설성면  기타(쓰레기 화재등)  화학적 발화열
# 4       2019-01-01 1:06    부산광역시  부산진구   당감동       건축,구조물     작동기기
# ...                 ...      ...   ...   ...          ...      ...
# 40098  2019-12-31 22:33      경기도   파주시   광탄면       건축,구조물     작동기기
# 40099  2019-12-31 22:45     경상북도   경산시   남방동       건축,구조물       미상
# 40100  2019-12-31 22:47    부산광역시    남구   문현동       건축,구조물     작동기기
# 40101  2019-12-31 23:05  제주특별자치도   제주시  외도일동       건축,구조물     작동기기
# 40102  2019-12-31 23:18    인천광역시   남동구   고잔동       건축,구조물     작동기기
#
#           발화열원소분류 발화요인대분류       발화요인소분류   최초착화물대분류           최초착화물소분류  \
# 0              폭죽     부주의          폭죽놀이  종이,목재,건초등             풀, 나뭇잎
# ...

# %%
iris['장소대분류'].value_counts()
# Out:
# 주거           11058
# 기타            7020
# 산업시설          5429
# 자동차,철도차량      4710
# 생활서비스         4045
# 판매,업무시설       2415
# 임야            2211
# 기타서비스         1811
# 집합시설           343
# 의료,복지시설        338
# 교육시설           314
# 운수자동차시설        269
# 선박,항공기         108
# 위험물,가스제조소       29
# 문화재시설            3
# Name: 장소대분류, dtype: int64

# %%
iris['화재유형'].value_counts()
# Out:
# 건축,구조물         26025
# 기타(쓰레기 화재등)     7020
# 자동차,철도차량        4710
# 임야              2211
# 선박,항공기           108
# 위험물,가스제조소등        29
# Name: 화재유형, dtype: int64

# %%
iris_gb = iris.groupby('장소대분류').count()
iris_gb
# Out:
#            화재발생년월일     시도  시·군·구    읍면동   화재유형  발화열원대분류  발화열원소분류  발화요인대분류  \
# 장소대분류
# 교육시설           314    314    314    314    314      314      314      314
# 기타            7020   7020   7020   7020   7020     7020     7020     7020
# 기타서비스         1811   1811   1811   1811   1811     1811     1811     1811
# 문화재시설            3      3      3      3      3        3        3        3
# 산업시설          5429   5429   5429   5429   5429     5429     5429     5429
# 생활서비스         4045   4045   4045   4045   4045     4045     4045     4045
# 선박,항공기         108    108    108    108    108      108      108      108
# 운수자동차시설        269    269    269    269    269      269      269      269
# 위험물,가스제조소       29     29     29     29     29       29       29       29
# 의료,복지시설        338    338    338    338    338      338      338      338
# 임야            2211   2211   2211   2211   2211     2211     2211     2211
# 자동차,철도차량      4710   4710   4710   4710   4710     4710     4710     4710
# ...

# %%
iris_gb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 교육시설 to 판매,업무시설
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   화재발생년월일    15 non-null     int64
#  1   시도         15 non-null     int64
#  2   시·군·구      15 non-null     int64
#  3   읍면동        15 non-null     int64
#  4   화재유형       15 non-null     int64
#  5   발화열원대분류    15 non-null     int64
#  6   발화열원소분류    15 non-null     int64
#  7   발화요인대분류    15 non-null     int64
#  8   발화요인소분류    15 non-null     int64
#  9   최초착화물대분류   15 non-null     int64
#  10  최초착화물소분류   15 non-null     int64
#  11  인명피해(명)소계  15 non-null     int64
#  12  사망         15 non-null     int64
#  13  부상         15 non-null     int64
#  14  재산피해소계     15 non-null     int64
#  15  장소중분류      15 non-null     int64
#  16  장소소분류      15 non-null     int64
# dtypes: int64(17)
# memory usage: 2.1+ KB

# %%
df2 = pd.read_csv('./scv.csv', \
                  usecols=['장소대분류','재산피해소계'],encoding='cp949')
df2
# Out:
#        재산피해소계     장소대분류
# 0           0        기타
# 1       14900        주거
# 2        3642  자동차,철도차량
# 3        1848        기타
# 4          45     기타서비스
# ...       ...       ...
# 40098   23707      산업시설
# 40099    3542      산업시설
# 40100       0   판매,업무시설
# 40101     105   판매,업무시설
# 40102    3879      산업시설
#
# [40103 rows x 2 columns]

# %%
g2=df2.groupby('장소대분류')
g2_gb=g2.sum()
g2_gb
# Out:
#               재산피해소계
# 장소대분류
# 교육시설         4209031
# 기타           7633013
# 기타서비스       10658338
# 문화재시설          11501
# 산업시설       345119597
# 생활서비스       18158352
# 선박,항공기      60005851
# 운수자동차시설      3959347
# 위험물,가스제조소    6805927
# 의료,복지시설      2453454
# 임야         198547953
# 자동차,철도차량    32663468
# 주거          62718223
# 집합시설         3182665
# 판매,업무시설    102369514

# %%
plt.rc('font', family='Malgun Gothic')
g2_gb['재산피해소계'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='장소대분류'>

# %%
plt.rc('font', family='Malgun Gothic')
iris_gb['장소소분류'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (8,5)
