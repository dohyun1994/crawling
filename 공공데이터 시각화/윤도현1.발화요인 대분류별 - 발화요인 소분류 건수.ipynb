# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('./fire_2019_eng.csv', \
                encoding='cp949', usecols=['Cause1', 'Cause2'])
df
# Out:
#        Cause1        Cause2
# 0         부주의          폭죽놀이
# 1          미상            미상
# 2          미상            미상
# 3      화학적 요인          자연발화
# 4      전기적 요인   절연열화에 의한 단락
# ...       ...           ...
# 40098  전기적 요인   접촉불량에 의한 단락
# 40099      미상            미상
# 40100     부주의       음식물 조리중
# 40101     부주의      가연물 근접방치
# 40102  전기적 요인  압착,손상에 의한 단락
#
# [40103 rows x 2 columns]

# %%
df.head(10)
# Out:
#    Cause1       Cause2
# 0     부주의         폭죽놀이
# 1      미상           미상
# 2      미상           미상
# 3  화학적 요인         자연발화
# 4  전기적 요인  절연열화에 의한 단락
# 5     부주의      음식물 조리중
# 6      방화           방화
# 7     부주의      음식물 조리중
# 8     부주의      음식물 조리중
# 9     부주의         담배꽁초

# %%
# columns 확인
df.columns
# Out:
# Index(['Cause1', 'Cause2'], dtype='object')

# %%
df.describe(include='object')
# Out:
#        Cause1 Cause2
# count   40103  40103
# unique     11     45
# top       부주의   담배꽁초
# freq    20149   5989

# %%
# Cause1(발화요인대분류) 컬럼으로 그룹화
gb1=df.groupby(by='Cause1')
gb1

# %%
# 그룹화한 row 갯수
gb1.count()
# Out:
#           Cause2
# Cause1
# 가스누출(폭발)     162
# 교통사고         433
# 기계적 요인      4046
# 기타           452
# 미상          3778
# 방화           370
# 방화의심         435
# 부주의        20149
# 자연적인 요인      195
# 전기적 요인      9459
# 화학적 요인       624

# %%
gb2 = df.groupby(['Cause1', 'Cause2'])
gb2.count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(가스누출(폭발), 가스누출(폭발)), (교통사고, 교통사고), (기계적 요인, 과열, 과부하), (기계적 요인, 기타(기계적요인)), (기계적 요인, 노후), (기계적 요인, 수동제어 실패), (기계적 요인, 역화), (기계적 요인, 오일,연료누설), (기계적 요인, 자동제어 실패), (기계적 요인, 정비불량), (기타, 기타), (미상, 미상), (방화, 방화), (방화의심, 방화의심), (부주의, 가연물 근접방치), (부주의, 기타(부주의)), (부주의, 논,임야태우기), (부주의, 담배꽁초), (부주의, 불씨,불꽃,화원방치), (부주의, 불장난), (부주의, 빨래삶기), (부주의, 쓰레기 소각), (부주의, 용접, 절단, 연마), (부주의, 유류 취급중), (부주의, 음식물 조리중), (부주의, 폭죽놀이), (자연적인 요인, 기타(자연적인요인)), (자연적인 요인, 돋보기 효과), (자연적인 요인, 자연적 재해), (전기적 요인, 과부하/과전류), (전기적 요인, 기타(전기적요인)), (전기적 요인, 누전,지락), (전기적 요인, 미확인단락), (전기적 요인, 반단선), (전기적 요인, 압착,손상에 의한 단락), (전기적 요인, 절연열화에 의한 단락), (전기적 요인, 접촉불량에 의한 단락), (전기적 요인, 층간단락), (전기적 요인, 트래킹에 의한 단락), (화학적 요인, 금수성물질의 물과 접촉), (화학적 요인, 기타(화학적요인)), (화학적 요인, 자연발화), (화학적 요인, 혼촉발화), (화학적 요인, 화학적 발화(유증기 확산)), (화학적 요인, 화학적 폭발)]

# %%
gb2.count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(가스누출(폭발), 가스누출(폭발)), (교통사고, 교통사고), (기계적 요인, 과열, 과부하), (기계적 요인, 기타(기계적요인)), (기계적 요인, 노후), (기계적 요인, 수동제어 실패), (기계적 요인, 역화), (기계적 요인, 오일,연료누설), (기계적 요인, 자동제어 실패), (기계적 요인, 정비불량), (기타, 기타), (미상, 미상), (방화, 방화), (방화의심, 방화의심), (부주의, 가연물 근접방치), (부주의, 기타(부주의)), (부주의, 논,임야태우기), (부주의, 담배꽁초), (부주의, 불씨,불꽃,화원방치), (부주의, 불장난), (부주의, 빨래삶기), (부주의, 쓰레기 소각), (부주의, 용접, 절단, 연마), (부주의, 유류 취급중), (부주의, 음식물 조리중), (부주의, 폭죽놀이), (자연적인 요인, 기타(자연적인요인)), (자연적인 요인, 돋보기 효과), (자연적인 요인, 자연적 재해), (전기적 요인, 과부하/과전류), (전기적 요인, 기타(전기적요인)), (전기적 요인, 누전,지락), (전기적 요인, 미확인단락), (전기적 요인, 반단선), (전기적 요인, 압착,손상에 의한 단락), (전기적 요인, 절연열화에 의한 단락), (전기적 요인, 접촉불량에 의한 단락), (전기적 요인, 층간단락), (전기적 요인, 트래킹에 의한 단락), (화학적 요인, 금수성물질의 물과 접촉), (화학적 요인, 기타(화학적요인)), (화학적 요인, 자연발화), (화학적 요인, 혼촉발화), (화학적 요인, 화학적 발화(유증기 확산)), (화학적 요인, 화학적 폭발)]

# %%
gb3 = df.groupby(['Cause1', 'Cause2'])[['Cause2']]
gb3.count()
# Out:
#                          Cause2
# Cause1   Cause2
# 가스누출(폭발) 가스누출(폭발)           162
# 교통사고     교통사고               433
# 기계적 요인   과열, 과부하           2481
#          기타(기계적요인)          437
#          노후                 279
#          수동제어 실패             33
#          역화                  25
#          오일,연료누설            317
#          자동제어 실패            293
#          정비불량               181
# 기타       기타                 452
# 미상       미상                3778
# 방화       방화                 370
# 방화의심     방화의심               435
# 부주의      가연물 근접방치          1256
#          기타(부주의)           1530
#          논,임야태우기            894
#          담배꽁초              5989
#          불씨,불꽃,화원방치        2796
#          불장난                147
#          빨래삶기               106
#          쓰레기 소각            2589
#          용접, 절단, 연마        1193
#          유류 취급중              87
#          음식물 조리중           3532
#          폭죽놀이                30
# 자연적인 요인  기타(자연적인요인)         109
# ...

# %%
Cause1_count = df['Cause1'].value_counts()[:11]
for idx, (val, cnt) in enumerate(Cause1_count.iteritems(), 1):
    print("Top", idx, ":", val, cnt)
# Out:
# Top 1 : 부주의 20149
# Top 2 : 전기적 요인 9459
# Top 3 : 기계적 요인 4046
# Top 4 : 미상 3778
# Top 5 : 화학적 요인 624
# Top 6 : 기타 452
# Top 7 : 방화의심 435
# Top 8 : 교통사고 433
# Top 9 : 방화 370
# Top 10 : 자연적인 요인 195
# Top 11 : 가스누출(폭발) 162

# %%
gb1=df.groupby(by='Cause1')
gb1.count()
# Out:
#           Cause2
# Cause1
# 가스누출(폭발)     162
# 교통사고         433
# 기계적 요인      4046
# 기타           452
# 미상          3778
# 방화           370
# 방화의심         435
# 부주의        20149
# 자연적인 요인      195
# 전기적 요인      9459
# 화학적 요인       624

# %%
gb1=df.groupby(['Cause1'])[['Cause2']].count()
gb1
# Out:
#           Cause2
# Cause1
# 가스누출(폭발)     162
# 교통사고         433
# 기계적 요인      4046
# 기타           452
# 미상          3778
# 방화           370
# 방화의심         435
# 부주의        20149
# 자연적인 요인      195
# 전기적 요인      9459
# 화학적 요인       624

# %% [markdown]
# # 1. 가스누출(폭발) 건수

# %%
gb1 =df[(df['Cause1'] == '가스누출(폭발)')].groupby(by='Cause2')
gb1

# %%
gb1_gb=gb1.count()
gb1_gb
# Out:
#           Cause1
# Cause2
# 가스누출(폭발)     162

# %%
plt.rc('font', family='Malgun Gothic')
gb1_gb['Cause1'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,5)

# %%
gb1 =df[(df['Cause1'] == '가스누출(폭발)')].groupby(by='Cause2')
gb1

# %% [markdown]
# # 2. 교통사고 건수

# %%
gb2 =df[(df['Cause1'] == '교통사고')].groupby(by='Cause2')
gb2

# %%
gb2_gb=gb2.count()
gb2_gb
# Out:
#         Cause1
# Cause2
# 교통사고       433

# %%
plt.rc('font', family='Malgun Gothic')
gb2_gb['Cause1'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,5)

# %% [markdown]
# # 3. 기계적 요인 건수

# %%
gb3 =df[(df['Cause1'] == '기계적 요인')].groupby(by='Cause2')
gb3

# %%
gb3_gb=gb3.count()
gb3_gb
# Out:
#            Cause1
# Cause2
# 과열, 과부하      2481
# 기타(기계적요인)     437
# 노후            279
# 수동제어 실패        33
# 역화             25
# 오일,연료누설       317
# 자동제어 실패       293
# 정비불량          181

# %%
plt.rc('font', family='Malgun Gothic')
gb3_gb['Cause1'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,5)

# %% [markdown]
# # 4. 기타 요인 건수

# %%
gb4 =df[(df['Cause1'] == '기타')].groupby(by='Cause2')
gb4

# %%
gb4_gb=gb4.count()
gb4_gb
# Out:
#         Cause1
# Cause2
# 기타         452

# %%
plt.rc('font', family='Malgun Gothic')
gb4_gb['Cause1'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,5)

# %% [markdown]
# # 5. 미상 건수

# %%
gb5 =df[(df['Cause1'] == '미상')].groupby(by='Cause2')
gb5

# %%
gb5_gb=gb5.count()
gb5_gb
# Out:
#         Cause1
# Cause2
# 미상        3778

# %%
plt.rc('font', family='Malgun Gothic')
gb5_gb['Cause1'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,5)

# %% [markdown]
# # 6. 방화 건수

# %%
gb6 =df[(df['Cause1'] == '방화')].groupby(by='Cause2')
gb6

# %%
gb6_gb=gb6.count()
gb6_gb
# Out:
#         Cause1
# Cause2
# 방화         370

# %%
plt.rc('font', family='Malgun Gothic')
gb6_gb['Cause1'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,5)

# %% [markdown]
# # 7. 방화의심 건수

# %%
gb7 =df[(df['Cause1'] == '방화의심')].groupby(by='Cause2')
gb7

# %%
gb7_gb=gb7.count()
gb7_gb
# Out:
#         Cause1
# Cause2
# 방화의심       435

# %%
plt.rc('font', family='Malgun Gothic')
gb7_gb['Cause1'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,5)

# %% [markdown]
# # 8. 부주의 건수

# %%
gb8 =df[(df['Cause1'] == '부주의')].groupby(by='Cause2')
gb8

# %%
gb8_gb=gb8.count()
gb8_gb
# Out:
#             Cause1
# Cause2
# 가연물 근접방치      1256
# 기타(부주의)       1530
# 논,임야태우기        894
# 담배꽁초          5989
# 불씨,불꽃,화원방치    2796
# 불장난            147
# 빨래삶기           106
# 쓰레기 소각        2589
# 용접, 절단, 연마    1193
# 유류 취급중          87
# 음식물 조리중       3532
# 폭죽놀이            30

# %%
plt.rc('font', family='Malgun Gothic')
gb8_gb['Cause1'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,5)

# %% [markdown]
# # 9. 자연적인 요인 건수

# %%
gb9 =df[(df['Cause1'] == '자연적인 요인')].groupby(by='Cause2')
gb9

# %%
gb9_gb=gb9.count()
gb9_gb
# Out:
#             Cause1
# Cause2
# 기타(자연적인요인)     109
# 돋보기 효과          23
# 자연적 재해          63

# %%
plt.rc('font', family='Malgun Gothic')
gb9_gb['Cause1'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,5)

# %% [markdown]
# # 10. 전기적 요인 건수

# %%
gb10 =df[(df['Cause1'] == '전기적 요인')].groupby(by='Cause2')
gb10

# %%
gb10_gb=gb10.count()
gb10_gb
# Out:
#               Cause1
# Cause2
# 과부하/과전류          779
# 기타(전기적요인)        619
# 누전,지락            321
# 미확인단락           2512
# 반단선              200
# 압착,손상에 의한 단락     558
# 절연열화에 의한 단락     2238
# 접촉불량에 의한 단락     1058
# 층간단락             106
# 트래킹에 의한 단락      1068

# %%
plt.rc('font', family='Malgun Gothic')
gb10_gb['Cause1'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,5)

# %% [markdown]
# # 11. 화학적 요인 건수

# %%
gb11 =df[(df['Cause1'] == '화학적 요인')].groupby(by='Cause2')
gb11

# %%
gb11_gb=gb11.count()
gb11_gb
# Out:
#                 Cause1
# Cause2
# 금수성물질의 물과 접촉        25
# 기타(화학적요인)           32
# 자연발화               427
# 혼촉발화                10
# 화학적 발화(유증기 확산)      77
# 화학적 폭발              53

# %%
plt.rc('font', family='Malgun Gothic')
gb11_gb['Cause1'].plot(kind='bar')
plt.rcParams["figure.figsize"] = (10,5)
