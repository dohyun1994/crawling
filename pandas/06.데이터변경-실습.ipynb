# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 컬럼
# #### 컬럼 추가

# %%
df['Age_Kor'] = df['Age'] +1
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Age_Kor
# 0      0  A/5 21171   7.2500   NaN        S     23.0
# 1      0   PC 17599  71.2833   C85        C     39.0

# %% [markdown]
# - Age, Age_kor / 상위 5개

# %%
df[['Age', 'Age_Kor']].head(5)
# Out:
#     Age  Age_Kor
# 0  22.0     23.0
# 1  38.0     39.0
# 2  26.0     27.0
# 3  35.0     36.0
# 4  35.0     36.0

# %%
df['new_col_1'] = df['Age'] + df['Fare']
df[['Age', 'Fare', 'new_col_1']].head(5)
# Out:
#     Age     Fare  new_col_1
# 0  22.0   7.2500    29.2500
# 1  38.0  71.2833   109.2833
# 2  26.0   7.9250    33.9250
# 3  35.0  53.1000    88.1000
# 4  35.0   8.0500    43.0500

# %%
df[(df['Age'] + df['Fare']) != (df['new_col_1'])] [['Age', 'Fare', 'new_col_1']]
# Out:
#      Age     Fare  new_col_1
# 5    NaN   8.4583        NaN
# 17   NaN  13.0000        NaN
# 19   NaN   7.2250        NaN
# 26   NaN   7.2250        NaN
# 28   NaN   7.8792        NaN
# ..   ...      ...        ...
# 859  NaN   7.2292        NaN
# 863  NaN  69.5500        NaN
# 868  NaN   9.5000        NaN
# 878  NaN   7.8958        NaN
# 888  NaN  23.4500        NaN
#
# [177 rows x 3 columns]

# %%
df['new_col_2'] = np.nan
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_Kor  new_col_1  \
# 0      0         A/5 21171   7.2500   NaN        S     23.0    29.2500
# 1      0          PC 17599  71.2833   C85        C     39.0   109.2833
# 2      0  STON/O2. 3101282   7.9250   NaN        S     27.0    33.9250
#
#    new_col_2
# 0        NaN
# 1        NaN
# 2        NaN

# %% [markdown]
# #### 컬럼 변경

# %%
df['new_col_2'] = 2
df[['new_col_2']].head(3)
# Out:
#     Age  new_col_2
# 0  22.0          2
# 1  38.0          2
# 2  26.0          2

# %%
df['new_col_2'] = df['Age'] + 10
df[['Age', 'new_col_2']].head(3)
# Out:
#     Age  new_col_2
# 0  22.0       32.0
# 1  38.0       48.0
# 2  26.0       36.0

# %%
# drop
#df.drop('Age_Kor', axis=1, inplace=True)
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new_col_1',
#        'new_col_2'],
#       dtype='object')

# %%
'Age_Kor' in df.columns
# Out:
# False

# %%
del df['new_col_2']
'new_col_2' in df.columns
# Out:
# False

# %%
df.drop(['Cabin', 'Embarked'], axis=1).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'new_col_1'],
#       dtype='object')

# %%
del [ df['Cabin'] , df['Embarked'] ]
df.columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cabin'
#
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'new_col_1'],
#       dtype='object')

# %% [markdown]
# ### Data(row)

# %% [markdown]
# #### data(row) 추가
# - list
# - dictionary

# %%
df = pd.read_csv('./train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# - list 추가

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
list_891 = [1, 1, 1, 'a', 'male', 70.0, 1, 0, 'b', 1, 'c', 'd']
df.loc[891] = list_891
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
# 891            1         1       1                    a  male  70.0      1
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q
# 891      0       b  1.00     c        d

# %%
dic_892 = {'PassengerId':1, 'Survived':1, 'Pclass':2, 'Name':'g', 'Sex': 'female', 'Age':68.0, 'SibSp':1, 'Parch':0, 'Ticket':'h', 'Fare':1, 'Cabin':'j', 'Embarked':'k'}
df.loc[892] = dic_892
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick    male  32.0      0
# 891            1         1       1                    a    male  70.0      1
# 892            1         1       2                    g  female  68.0      1
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q
# 891      0       b  1.00     c        d
# 892      0       h  1.00     j        k

# %% [markdown]
# #### data(row)변경

# %%
df.loc[1] = list_891
df.head(3)
# Out:
#    PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 0            1         0       3  Braund, Mr. Owen Harris    male  22.0
# 1            1         1       1                        a    male  70.0
# 2            3         1       3   Heikkinen, Miss. Laina  female  26.0
#
#    SibSp  Parch            Ticket   Fare Cabin Embarked
# 0      1      0         A/5 21171  7.250   NaN        S
# 1      1      0                 b  1.000     c        d
# 2      0      0  STON/O2. 3101282  7.925   NaN        S

# %%
df.loc[3] = dic_892
df.head(4)
# Out:
#    PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 0            1         0       3  Braund, Mr. Owen Harris    male  22.0
# 1            1         1       1                        a    male  70.0
# 2            3         1       3   Heikkinen, Miss. Laina  female  26.0
# 3            1         1       2                        g  female  68.0
#
#    SibSp  Parch            Ticket   Fare Cabin Embarked
# 0      1      0         A/5 21171  7.250   NaN        S
# 1      1      0                 b  1.000     c        d
# 2      0      0  STON/O2. 3101282  7.925   NaN        S
# 3      1      0                 h  1.000     j        k

# %% [markdown]
# #### data(row)삭제

# %%
# axis = 0이 default
df.drop(892, axis=0, implace=True)
df.tail(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2512/2958949354.py in <module>
#       1 # axis = 0이 default
# ----> 2 df.drop(892, axis=0, implace=True)
#       3 df.tail(2)
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: drop() got an unexpected keyword argument 'implace'

# %% [markdown]
# ### 특정 data 변경

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 0            1         0       3  Braund, Mr. Owen Harris    male  22.0
# 1            1         1       1                        a    male  70.0
# 2            3         1       3   Heikkinen, Miss. Laina  female  26.0
#
#    SibSp  Parch            Ticket   Fare Cabin Embarked
# 0      1      0         A/5 21171  7.250   NaN        S
# 1      1      0                 b  1.000     c        d
# 2      0      0  STON/O2. 3101282  7.925   NaN        S

# %%
df.loc[2, 'Name'] = 'No name'
df.head(3)
# Out:
#    PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 0            1         0       3  Braund, Mr. Owen Harris    male  22.0
# 1            1         1       1                        a    male  70.0
# 2            3         1       3                  No name  female  26.0
#
#    SibSp  Parch            Ticket   Fare Cabin Embarked
# 0      1      0         A/5 21171  7.250   NaN        S
# 1      1      0                 b  1.000     c        d
# 2      0      0  STON/O2. 3101282  7.925   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 893 entries, 0 to 892
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  893 non-null    int64
#  1   Survived     893 non-null    int64
#  2   Pclass       893 non-null    int64
#  3   Name         893 non-null    object
#  4   Sex          893 non-null    object
#  5   Age          716 non-null    float64
#  6   SibSp        893 non-null    int64
#  7   Parch        893 non-null    int64
#  8   Ticket       893 non-null    object
#  9   Fare         893 non-null    float64
#  10  Cabin        206 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 123.0+ KB

# %% [markdown]
# - 나이가 70 넘으신 분의 나이를 0으로 변경

# %%
df[df['Age']> 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df.loc[df['Age'] > 70, 'Age']= 0
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 1              1         1       1                                         a
# 2              3         1       3                                   No name
# 3              1         1       2                                         g
# 4              5         0       3                  Allen, Mr. William Henry
# ..           ...       ...     ...                                       ...
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
# 891            1         1       1                                         a
# 892            1         1       2                                         g
#
# ...

# %% [markdown]
# ### 컬럼 타입/ 명 변경
# - astype
#     - implace option이 없음
# - 변경할 컬럼의 data중 nan이 없으면

# %%
df = df.astype({'SibSp':'float'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 893 entries, 0 to 892
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  893 non-null    int64
#  1   Survived     893 non-null    int64
#  2   Pclass       893 non-null    int64
#  3   Name         893 non-null    object
#  4   Sex          893 non-null    object
#  5   Age          716 non-null    float64
#  6   SibSp        893 non-null    float64
#  7   Parch        893 non-null    int64
#  8   Ticket       893 non-null    object
#  9   Fare         893 non-null    float64
#  10  Cabin        206 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 123.0+ KB

# %%
df = df.astype({'Age': 'int'})
df.info()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2512/953019811.py in <module>
# ----> 1 df = df.astype({'Age': 'int'})
#       2 df.info()
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5797                 if col_name in dtype:
#    5798                     results.append(
# -> 5799                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5800                     )
#    5801                 else:
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...
