# %%
import numpy as np

# %% [markdown]
# ### 통계
# - mean

# %%
arr1 = np.random.rand(10).reshape(2, 5)
print(arr1)
# Out:
# [[0.82395085 0.18910573 0.67523486 0.57254901 0.77710206]
#  [0.53219793 0.45882582 0.81889402 0.03597805 0.62630009]]

# %%
np.mean(arr1)
# Out:
# 0.5510138420375015

# %%
arr1.mean()
# Out:
# 0.5510138420375015

# %%
np.max(arr1)
# Out:
# 0.8239508460637132

# %%
arr1.max()
# Out:
# 0.8239508460637132

# %%
np.argmax(arr1)
# Out:
# 0

# %%
np.min(arr1)
# Out:
# 0.03597805421951916

# %%
arr1.min()
# Out:
# 0.03597805421951916

# %%
# 가장 작은 값의 index
arr1.argmin()
# Out:
# 8

# %%
# 표준편차
np.std(arr1)
# Out:
# 0.24980491264979005
