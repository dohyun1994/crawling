# %% [markdown]
# #### pandas란
# - 2차원(row, column)형태의 데이터를 분석하기 위한 라이브러리
# - 대용량 data 분석이 가능하며 배열 계산에 빠른 numpy를 기반으로 설계
# - pandas 개발자는 금융회사의 분석 전문가로 회사의 data 분석 툴이 마음에 들지 않아 직접 분석 툴을 개발 하고 성능이 좋아 회사의 다른 사람들에게 공유하였고 점점 사용자가 늘면서 전 세계적으로 사용하게 됨
# - 2차원 데이터 분석 툴 중에 가장 인기가 있음
# - Series, DataFrame, Index의 이해 필요
# - 별칭으로 pd를 쓰는 것이 관례임 => import pandas as pd

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Serise
# - Column이 하나인 1차원 형태의 Data
# - numpy의 ndarray가 보강
# - Index와 Data를 지님
# - Series가 모여 2차원 형태의 Data가 되고 이를 DataFrame이라 함

# %% [markdown]
# #### 생성
# - list data
# - list data + index
# - list data + index + dtype(데이타타입)
# - dictionary

# %%
st = pd.Series([1, 2, 3, 4])
st
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
print(type(st))
# Out:
# <class 'pandas.core.series.Series'>

# %%
st.values
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
st.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
st.index.values
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
type(st.values)
# Out:
# numpy.ndarray

# %%
st.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s3 = pd.Series(np.arange(1, 100, 2), np.arange(1, 51))
s3
# Out:
# 1      1
# 2      3
# 3      5
# 4      7
# 5      9
# 6     11
# 7     13
# 8     15
# 9     17
# 10    19
# 11    21
# 12    23
# 13    25
# 14    27
# 15    29
# 16    31
# 17    33
# 18    35
# 19    37
# 20    39
# 21    41
# 22    43
# 23    45
# 24    47
# 25    49
# 26    51
# 27    53
# 28    55
# 29    57
# 30    59
# 31    61
# 32    63
# 33    65
# 34    67
# 35    69
# 36    71
# 37    73
# 38    75
# 39    77
# 40    79
# 41    81
# 42    83
# 43    85
# 44    87
# 45    89
# 46    91
# 47    93
# 48    95
# 49    97
# 50    99
# dtype: int32

# %%
# datatype 지정
s4 = pd.Series( [1, 2, 3, 4, 5], dtype=object)
print(s4)
s5 = pd.Series( [1, 2, 3, 4, 5], dtype=float)
print(s5)
s6 = pd.Series( [1, 2, 3, 4, 5], dtype=int)
print(s6)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: object
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
print(s4.dtype)
s4 = s4.astype('float')
s4
# Out:
# object
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %%
# dictionary
dic_1 = {
    'kor' : 90,
    'eng' : 95,
    'mat' : 87,
    'sci' : 88
}
dic_1
# Out:
# {'kor': 90, 'eng': 95, 'mat': 87, 'sci': 88}

# %%
s7 = pd.Series(dic_1)
s7
# Out:
# kor    90
# eng    95
# mat    87
# sci    88
# dtype: int64

# %%
s = pd.Series([1, 2, 3, 4, 5], ['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
s.index.values
# Out:
# array(['a', 'b', 'c', 'd', 'e'], dtype=object)

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
print(s['b'])
print(s['c'])
# Out:
# 2
# 3

# %%
s['b'] = 100
s['e'] = 101
print(s['b'])
print(s['e'])
print(s.values)
# Out:
# 100
# 101
# [  1 100   3   4 101]

# %%
# index 변경
s.index = ['가', '나', '다', '라', '마']
s
# Out:
# 가      1
# 나    100
# 다      3
# 라      4
# 마    101
# dtype: object

# %%
s['나']
# Out:
# 100

# %%
# 인덱스 재사용
s1 = pd.Series(np.arange(5), s.index)
s1
# Out:
# 가    0
# 나    1
# 다    2
# 라    3
# 마    4
# dtype: int32

# %%
s1[['나', '라']]
# Out:
# 나    1
# 라    3
# dtype: int32

# %%
s1['나': '라']
# Out:
# 나    1
# 다    2
# 라    3
# dtype: int32

# %%
s1.drop('나')
s1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6756/3201610849.py in <module>
# ----> 1 s1.drop('나')
#       2 s1
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4677         dtype: float64
#    4678         """
# -> 4679         return super().drop(
#    4680             labels=labels,
#    4681             axis=axis,
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# c:\users\yj\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['나'] not found in axis"

# %%
s1 = s1.drop('나')
s1
# Out:
# 가    0
# 다    2
# 라    3
# 마    4
# dtype: int32

# %%
s1 = s1.drop('다')
s1
# Out:
# 가    0
# 라    3
# 마    4
# dtype: int32

# %%
s1 = s1.drop('가')
s1
# Out:
# 라    3
# 마    4
# dtype: int32

# %%
# 바로 삭제
del s1['마']
s1
# Out:
# 라    3
# dtype: int32
